# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("Housing.csv")
df
# Out:
#      rownames   price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1   42000     5850         3        1        2      yes      no
# 1           2   38500     4000         2        1        1      yes      no
# 2           3   49500     3060         3        1        1      yes      no
# 3           4   60500     6650         3        1        2      yes     yes
# 4           5   61000     6360         2        1        1      yes      no
# ..        ...     ...      ...       ...      ...      ...      ...     ...
# 541       542   91500     4800         3        2        4      yes     yes
# 542       543   94000     6000         3        2        4      yes      no
# 543       544  103000     6000         3        2        4      yes     yes
# 544       545  105000     6000         3        2        2      yes     yes
# 545       546  105000     6000         3        1        2      yes      no
#
#     fullbase gashw airco  garagepl prefarea
# ...

# %%
df.isnull().sum()
# Out:
# rownames    0
# price       0
# lotsize     0
# bedrooms    0
# bathrms     0
# stories     0
# driveway    0
# recroom     0
# fullbase    0
# gashw       0
# airco       0
# garagepl    0
# prefarea    0
# dtype: int64

# %%
import math # importing math to convert the values from float to integer
median_bedrooms = math.floor(df.bedrooms.median())
median_bedrooms
# Out:
# 3

# %%
df_bedrooms = df.bedrooms.fillna(median_bedrooms)

# %%
df_bedrooms
# Out:
# 0      3
# 1      2
# 2      3
# 3      3
# 4      2
#       ..
# 541    3
# 542    3
# 543    3
# 544    3
# 545    3
# Name: bedrooms, Length: 546, dtype: int64

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["lotsize","bedrooms","bathrms"]],df.price)  # target variable is price and other three are the independent variables
# Out:
# LinearRegression()

# %%
reg.coef_ # m
# Out:
# array([5.41120044e+00, 5.82680241e+03, 1.97502101e+04])

# %%
reg.intercept_ # c
# Out:
# np.float64(-2418.2926167407713)

# %%
# predicting
reg.predict([[3080, 2, 1]]) # ([lotsize, bedrooms, bathroms]) we are predicting y or price of it
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([45652.01970535])

# %%
# lets check how did it get
#y = m1*lotsize+m2*bedrooms+m3*bathrooms+c
m1 = 5.41120044e+00
m2 = 5.82680241e+03
m3 = 1.97502101e+04
x1 = 3080
x2 = 2
x3 = 1
c = -2418.2926167407713
y = m1*x1+m2*x2+m3*x3+c
y
# Out:
# 45652.019658459234
